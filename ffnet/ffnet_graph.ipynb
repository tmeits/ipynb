# %%
# %matplotlib inline
from ffnet import mlgraph, ffnet
import networkx as nx
import pylab

conec = mlgraph((2,4,6,1), biases=False)
net = ffnet(conec)
#nx.draw(net.graph)
nx.draw_networkx(net.graph, with_labels=True)
#nx.draw_circular(net.graph)
#nx.draw_spring(net.graph)
#nx.draw_shell(net.graph)
#nx.draw_random(net.graph)
#nx.draw_graphviz(net.graph, prog='dot')
pylab.show()
